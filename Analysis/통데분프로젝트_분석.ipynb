# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats

rate=pd.read_excel("movie_rate.xlsx")
movie=pd.read_csv("ALL_KC_KOBIS_BOX_OFFIC_MOVIE_INFO.csv")
movie=movie[(movie['GRAD_NM']!='청소년관람불가') & (movie['NLTY_NM']=='한국')]

# %%
rate
# Out:
#       NO                   제목  \
# 0      1                 산상수훈
# 1      2                 교회오빠
# 2      3                  기생충
# 3      4                  엑시트
# 4      5                  김복동
# ..   ...                  ...
# 548  549              정직한 후보2
# 549  550                   주연
# 550  551  쥬라기캅스 극장판: 공룡시대 대모험
# 551  552              프린세스 아야
# 552  553                  홈리스
#
#                                                    url  평론가 평점  네티즌 평점
# 0    https://movie.naver.com/movie/bi/mi/basic.nave...    3.00    6.30
# 1    https://movie.naver.com/movie/bi/mi/basic.nave...     NaN    9.31
# 2    https://movie.naver.com/movie/bi/mi/basic.nave...    9.06    8.49
# 3    https://movie.naver.com/movie/bi/mi/basic.nave...     NaN     NaN
# 4    https://movie.naver.com/movie/bi/mi/basic.nave...    6.60    8.83
# ..                                                 ...     ...     ...
# 548  https://movie.naver.com/movie/bi/mi/basic.nave...    5.75    5.99
# 549  https://movie.naver.com/movie/bi/mi/basic.nave...     NaN    8.04
# 550  https://movie.naver.com/movie/bi/mi/basic.nave...    6.00    7.59
# 551  https://movie.naver.com/movie/bi/mi/basic.nave...    5.00    7.38
# 552  https://movie.naver.com/movie/bi/mi/basic.nave...     NaN     NaN
#
# [553 rows x 5 columns]

# %%
movie
# Out:
#         NO             MOVIE_NM DRCTR_NM              MAKR_NM INCME_CMPNY_NM  \
# 0        1                 산상수훈      유영의                (주)그란            NaN
# 1        2                 교회오빠      이호경        KBS,커넥트픽쳐스(주)            NaN
# 3        4                  기생충      봉준호           (주)바른손이앤에이            NaN
# 6        7                  엑시트      이상근      (주)외유내강,(주)필름케이            NaN
# 7        8                  김복동      송원근           한국탐사저널리즘센터            NaN
# ...    ...                  ...      ...                  ...            ...
# 4933  4934              정직한 후보2      장유정        (주)수필름,(주)홍필름            NaN
# 4935  4936                   주연      송원준                영화사 퐑            NaN
# 4938  4939  쥬라기캅스 극장판: 공룡시대 대모험      김호락            (주)스튜디오버튼            NaN
# 4949  4950              프린세스 아야      이성강  주식회사 다다쇼,(주)영화사레드피터            NaN
# 4953  4954                  홈리스      임승현        (주)타이거시네마,DGC            NaN
#
#            DISTB_CMPNY_NM    OPN_DE MOVIE_TY_NM MOVIE_STLE_NM NLTY_NM  \
# 0             이언픽쳐스,(주)그란  20171207        개봉영화            장편      한국
# 1               커넥트픽쳐스(주)  20190516        개봉영화            장편      한국
# 3               (주)씨제이이엔엠  20190530        개봉영화            장편      한국
# 6               (주)씨제이이엔엠  20190731        개봉영화            장편      한국
# 7                (주)엣나인필름  20190808        개봉영화            장편      한국
# ...                   ...       ...         ...           ...     ...
# 4933  (주)넥스트엔터테인먼트월드(NEW)  2022-09-        개봉영화            장편      한국
# 4935          (주)마노엔터테인먼트  2022-09-        개봉영화            장편      한국
# 4938        메가박스중앙(주)플러스엠  2022-09-        개봉영화            장편      한국
# 4949  씨제이 씨지브이(CJ CGV)(주)  2022-09-        개봉영화            장편      한국
# 4953           그린나래미디어(주)  2022-09-        개봉영화            장편      한국
#
#       TOT_SCRN_CO   SALES_PRICE  VIEWNG_NMPR_CO  SEOUL_SALES_PRICE  \
# 0            71.0  3.206000e+06           284.0          3206000.0
# 1           200.0  1.499000e+06           154.0          1499000.0
# 3          1948.0  1.575865e+09        227811.0        684991280.0
# 6          1660.0  2.000000e+05            40.0                0.0
# 7           366.0  7.700000e+05           110.0                0.0
# ...           ...           ...             ...                ...
# 4933          NaN           NaN             NaN                NaN
# 4935         20.0           NaN           363.0                NaN
# 4938        453.0           NaN             NaN                NaN
# 4949        348.0           NaN             NaN                NaN
# 4953         86.0           NaN             NaN                NaN
#
#       SEOUL_VIEWNG_NMPR_CO GENRE_NM   GRAD_NM MOVIE_SDIV_NM
# 0                    284.0      드라마     전체관람가       독립/예술영화
# 1                    154.0    다큐멘터리     전체관람가       독립/예술영화
# 3                  97354.0      드라마  15세이상관람가          일반영화
# 6                      0.0      코미디  12세이상관람가          일반영화
# 7                      0.0    다큐멘터리  12세이상관람가       독립/예술영화
# ...                    ...      ...       ...           ...
# 4933                   NaN      코미디  12세이상관람가          일반영화
# 4935                 302.0      드라마  12세이상관람가       독립/예술영화
# 4938                   NaN    애니메이션     전체관람가          일반영화
# 4949                   NaN      판타지     전체관람가          일반영화
# 4953                   NaN      드라마  12세이상관람가       독립/예술영화
#
# [553 rows x 18 columns]

# %%
movie['DISTB_CMPNY_NM'].unique()
# Out:
# array(['이언픽쳐스,(주)그란', '커넥트픽쳐스(주)', '(주)씨제이이엔엠', '(주)엣나인필름', '(주)영화사 진진',
#        '(주)엣나인필름,(주)콘텐츠판다', '(주)엣나인필름,CGV아트하우스', '(재)CBS,주식회사 마운틴픽쳐스',
#        '롯데컬처웍스(주)롯데엔터테인먼트', '(주)시네마달', '(주)에이스메이커무비웍스',
#        '(주)씨네포트,주식회사 마운틴픽쳐스', '(주)리틀빅픽쳐스', '(주)삼백상회', '(주)트리플픽쳐스',
#        '주식회사 마운틴픽쳐스', '씨네마캣 픽쳐스', 'CGV아트하우스', '메가박스중앙(주)플러스엠', '(주)이수C&E',
#        'KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)', '케이티하이텔(주)', '(주)드림팩트엔터테인먼트',
#        '㈜인디스토리', '(주)넥스트엔터테인먼트월드(NEW)', '영화배급협동조합 씨네소파',
#        '(주)씨제이이엔엠,(주)덱스터스튜디오', '(주)케이알씨지', '(주)영화사 그램', '주식회사 씨엠닉스',
#        '(주)미로스페이스', '(주)영화특별시에스엠씨', '(주)쇼박스', '메가박스중앙(주)플러스엠,(주)리틀빅픽쳐스',
#        '아이 엠', '스마트스터디(주)', '(주)랠리버튼', '영화사 무명', '찬란', '아이 엠,케이티하이텔(주)',
#        '제이리미디어', '주식회사 블루필름웍스', '(주)아이디어랩', '(주)그노스', '한국문화예술위원회',
#        '(주)스톰픽쳐스코리아,(주)삼백상회', '(주)유비네트워크', '(유)조이앤시네마,(주)제이앤씨미디어그룹',
#        '(주)마노엔터테인먼트', '영화사 삼순', '(주)스마일이엔티', '(주)영화사오원', '(주)에스와이코마드',
#        '(주)좋은 하늘,(주)박수엔터테인먼트', '(주)피터팬픽쳐스', '매치컷(주)', '에이 라이프',
#        '(주)퍼스트런,(주)키다리이엔티', '영화사 풀,(주)영화사 친구', '(주)라온컴퍼니플러스', '명필름랩',
#        '(주)디스테이션,롯데컬처웍스(주)롯데엔터테인먼트', '소니픽쳐스엔터테인먼트코리아주식회사극장배급지점,(주)키다리이엔티',
#        '씨제이포디플렉스 주식회사', 'ZONE Film', '(주)싸이더스,찬란', '(주)제이앤씨미디어그룹',
#        '다큐스토리', '(주)노바이앤티', '필름다빈', '(주)중헌홀딩스', '(주)스톰픽쳐스코리아,와이드 릴리즈(주)',
#        '(주)26컴퍼니', '(주)인디플러그', '비에이치제이시네마', '(주)박수엔터테인먼트', '주식회사 더쿱',
#        '예술의전당', '그린나래미디어(주)', '(주)에스와이코마드,아이 엠', '(주)률필름,㈜인디스토리',
#        '(주)이놀미디어', 'CGV ICECON,씨제이포디플렉스 주식회사', '(주)에이원엔터테인먼트',
#        '(주)키위미디어그룹,오퍼스픽쳐스(유),(주)씨네필운', '아방가르드 필름', 'CGV ICECON',
#        'TCO(주)더콘텐츠온', '시네마 뉴원', '민치앤필름', '(주)스튜디오 보난자', '워너브러더스 코리아(주)',
#        '(주)대교 미디어콘텐츠사업본부', '(주)리틀빅픽쳐스,(주)트리니티픽쳐스', '(주)인터오리진아이엔씨',
#        '호우주의보', '(주)유어스토리블루', '목영이엔엠,(주)다자인소프트', '(주)미로스페이스,(주)스튜디오 보난자',
#        '(주)콘텐츠윙', '하준사', '(주)백그림', '케이티하이텔(주),판씨네마(주)', '(주)메리크리스마스',
#        '(재)서울예술단', '목영이엔엠', 'M&M 인터내셔널', '(주)액티버스엔터테인먼트,예지림엔터테인먼트',
#        '주식회사 블루필름웍스,THE 픽쳐스', '(주)씨네필운', '(주)도어이앤엠',
#        '(주)아이필름코퍼레이션,씨제이 씨지브이(CJ CGV)(주)', '주식회사 컨텐츠썬,(주)아우라픽처스',
#        '메가박스중앙(주)플러스엠,(주)영화사울림', '(주)파인스토리', '(주)위즈온센',
#        '(주)영화제작전원사 ,(주)콘텐츠판다', '(주)케이티알파,판씨네마(주)', '유한회사 영화사 반딧불',
#        '(주)케이티알파,씨제이 씨지브이(CJ CGV)(주)', '(주)콘텐츠판다', '씨제이 씨지브이(CJ CGV)(주)',
#        '(주)명필름,(주)씨네필운', '마루아트센터(주)', '(주)디스테이션', '스마일픽쳐스', '강 컨텐츠',
#        '언더식스티,(주)퍼니콘', '(주)라이크콘텐츠', '(주)트리필름', '주식회사 플릭스코', '농부영화사',
#        '(주)케빈앤컴퍼니', '예지림엔터테인먼트', '(주)스튜디오디에이치엘', '와이드 릴리즈(주)', '이상우필름',
#        '(주)리틀빅픽쳐스,시네마6411', '(주)모쿠슈라', '(주)스토리제이', '한양제작소,(주)리틀빅픽쳐스',
#        '주식회사 필름초이스', '주식회사 에이비오엔터테인먼트,메가박스중앙(주)플러스엠', '(주)컨택트미디어',
#        '㈜인디스토리,엠앤씨에프', '(주)민치앤필름', '(주)그노스,(주)다날엔터테인먼트',
#        '(주)씨제이이엔엠,주식회사 티빙', '씨제이 씨지브이(CJ CGV)(주),CGV ICECON',
#        '주식회사 블루필름웍스,(주)영화사메이플러스', '(사)그라시아스합창단', '트윈플러스파트너스(주)',
#        '필름에이픽쳐스', '(주)씨네포트,주식회사 블루필름웍스', '(주)엣나인필름,(주)메타플레이',
#        '(주)스튜디오디에이치엘,(주)키다리스튜디오', '쉼표', 'TCO(주)더콘텐츠온,씨제이 씨지브이(CJ CGV)(주)',
#        '(주)마인드마크', '씨제이포디플렉스 주식회사,CGV ICECON', '(주)디오시네마,(주)태양미디어그룹',
#        '주식회사 케이엠스타', '(주)더존크리에이티브', '상남영화제작소',
#        '(주)드림팩트엔터테인먼트,주식회사 블루필름웍스', '주식회사 엔픽플,트윈플러스파트너스(주)',
#        '(주)지티지그룹,와이드 릴리즈(주)', '(주)블루라벨픽쳐스,디스트릭 몽', '(주)에픽캔', '김충길 필름',
#        'TCO(주)더콘텐츠온,(주)제이앤씨미디어그룹', '주식회사 왓챠', '(주)홈초이스,(주)싸이더스',
#        '(주)아우라픽처스', '(주)더쿱디스트리뷰션', '(주)디오시네마', '(주)로이비쥬얼', '오드',
#        '(주)디스테이션,주식회사 제이씨엔터웍스', '씨제이 씨지브이(CJ CGV)(주),씨제이포디플렉스 주식회사'],
#       dtype=object)

# %%
#유통사 앞의 하나만 사용
movie['DISTB_CMPNY_NM']
# Out:
# 0               이언픽쳐스,(주)그란
# 1                 커넥트픽쳐스(주)
# 3                 (주)씨제이이엔엠
# 6                 (주)씨제이이엔엠
# 7                  (주)엣나인필름
#                ...
# 4933    (주)넥스트엔터테인먼트월드(NEW)
# 4935            (주)마노엔터테인먼트
# 4938          메가박스중앙(주)플러스엠
# 4949    씨제이 씨지브이(CJ CGV)(주)
# 4953             그린나래미디어(주)
# Name: DISTB_CMPNY_NM, Length: 553, dtype: object

# %%
movie['DISTB_CMPNY_NM']=movie['DISTB_CMPNY_NM'].apply(lambda x: str(x).split(',')[0])

# %%
movie['DISTB_CMPNY_NM']
# Out:
# 0                     이언픽쳐스
# 1                 커넥트픽쳐스(주)
# 3                 (주)씨제이이엔엠
# 6                 (주)씨제이이엔엠
# 7                  (주)엣나인필름
#                ...
# 4933    (주)넥스트엔터테인먼트월드(NEW)
# 4935            (주)마노엔터테인먼트
# 4938          메가박스중앙(주)플러스엠
# 4949    씨제이 씨지브이(CJ CGV)(주)
# 4953             그린나래미디어(주)
# Name: DISTB_CMPNY_NM, Length: 553, dtype: object

# %%
import matplotlib as mpl
print(mpl.matplotlib_fname())
print(mpl.get_cachedir())
mpl.rcParams['font.family']='NanumGothic'
# Out:
# C:\Users\gus10\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# C:\Users\gus10\.matplotlib

# %%
import matplotlib.pyplot as plt
screenPrice=movie[movie['SALES_PRICE'].notna()]
groups = screenPrice.groupby('DISTB_CMPNY_NM')

fig, ax = plt.subplots()
for DISTB_CMPNY_NM, group in groups:
    ax.plot(group.TOT_SCRN_CO, 
            group.SALES_PRICE , 
            marker='o', 
            linestyle='',
            label=DISTB_CMPNY_NM)
ax.legend(fontsize=12, bbox_to_anchor=(1,1)) # legend position

plt.title('영화 매출과 스크린수', fontsize=20)

plt.xlabel('스크린 수', fontsize=14)

plt.ylabel('매출액', fontsize=14)

plt.show()

# %%
len(movie['DISTB_CMPNY_NM'].unique())
# Out:
# 148

# %%
sum(movie['SALES_PRICE'].notna())
# Out:
# 272

# %%
len(movie['DISTB_CMPNY_NM'])
# Out:
# 553

# %%
print(groups.size())
max(groups.size())
# Out:
# DISTB_CMPNY_NM
# (유)조이앤시네마    1
# (재)CBS       1
# (재)서울예술단     1
# (주)26컴퍼니     2
# (주)그노스       2
#             ..
# 케이티하이텔(주)    2
# 필름다빈         5
# 하준사          1
# 한국문화예술위원회    2
# 호우주의보        1
# Length: 103, dtype: int64
# 14

# %%
from scipy.stats import shapiro
#정규분포인지 확인 - 둘다 비정규
print(shapiro(screenPrice['SALES_PRICE'].dropna().values))
print(shapiro(screenPrice['TOT_SCRN_CO'].dropna().values))
# Out:
# ShapiroResult(statistic=0.29596585035324097, pvalue=6.340069688363416e-31)
# ShapiroResult(statistic=0.6365132927894592, pvalue=1.1522648273404511e-23)

# %%
#연속형-연속형, 비모수이므로 spearman 사용해서 분석
print(stats.spearmanr(screenPrice['SALES_PRICE'],screenPrice['TOT_SCRN_CO']))
# Out:
# SpearmanrResult(correlation=0.801947126406647, pvalue=2.3521206609749387e-62)
